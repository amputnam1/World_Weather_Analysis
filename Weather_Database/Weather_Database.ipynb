# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
import time
from citipy import citipy

import os, sys
currentdir = os.path.dirname(os.path.realpath("Weather_Database"))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
# Import API key
from config import weather_api_key

# Import linregress
from scipy.stats import linregress
import textwrap

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-56.000, high=80.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 910

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | kirakira
# Processing Record 5 of Set 1 | deniliquin
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | pokhara
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | zhanakorgan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | tautira
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | cortez
# Processing Record 14 of Set 1 | bria
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | teya
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | dicabisagan
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | limbang
# Processing Record 27 of Set 1 | calabozo
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | sembe
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | plettenberg bay
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | iisaku
# Processing Record 37 of Set 1 | hamilton
# Processing Record 38 of Set 1 | mayo
# Processing Record 39 of Set 1 | susuman
# Processing Record 40 of Set 1 | nizhnevartovsk
# Processing Record 41 of Set 1 | kazerun
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | liepaja
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | itapipoca
# Processing Record 46 of Set 1 | swellendam
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | bonthe
# Processing Record 50 of Set 1 | gamba
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | ternuvate
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | husavik
# Processing Record 5 of Set 2 | kuala terengganu
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | kodinar
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | cedar city
# Processing Record 11 of Set 2 | yerbogachen
# Processing Record 12 of Set 2 | port macquarie
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 2 | tam ky
# Processing Record 16 of Set 2 | ust-nera
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | san andres
# Processing Record 19 of Set 2 | florianopolis
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | terrace
# Processing Record 22 of Set 2 | port hedland
# Processing Record 23 of Set 2 | san policarpo
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | san pedro
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | peniche
# Processing Record 30 of Set 2 | merke
# Processing Record 31 of Set 2 | pangnirtung
# Processing Record 32 of Set 2 | mount isa
# Processing Record 33 of Set 2 | olds
# Processing Record 34 of Set 2 | kahului
# Processing Record 35 of Set 2 | portland
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | julio de castilhos
# Processing Record 39 of Set 2 | correntina
# Processing Record 40 of Set 2 | saint anthony
# Processing Record 41 of Set 2 | raurkela
# City not found. Skipping...
# Processing Record 42 of Set 2 | asau
# Processing Record 43 of Set 2 | baiyin
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | marmande
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | dickinson
# Processing Record 49 of Set 2 | urma
# Processing Record 50 of Set 2 | half moon bay
# Processing Record 1 of Set 3 | raikot
# Processing Record 2 of Set 3 | cuiaba
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | ballina
# Processing Record 5 of Set 3 | saint-augustin
# Processing Record 6 of Set 3 | verkhoyansk
# Processing Record 7 of Set 3 | jiangyou
# Processing Record 8 of Set 3 | hailar
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | jaunpur
# Processing Record 11 of Set 3 | saint-joseph
# Processing Record 12 of Set 3 | valkeakoski
# Processing Record 13 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 14 of Set 3 | dan khun thot
# Processing Record 15 of Set 3 | chara
# Processing Record 16 of Set 3 | maniitsoq
# Processing Record 17 of Set 3 | the valley
# Processing Record 18 of Set 3 | poum
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | tlacotepec
# Processing Record 22 of Set 3 | wairoa
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | lompoc
# Processing Record 25 of Set 3 | nogliki
# Processing Record 26 of Set 3 | paragominas
# Processing Record 27 of Set 3 | great falls
# Processing Record 28 of Set 3 | busselton
# Processing Record 29 of Set 3 | sao joao da barra
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | mhango
# Processing Record 32 of Set 3 | garowe
# Processing Record 33 of Set 3 | manzil jamil
# City not found. Skipping...
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | naze
# Processing Record 36 of Set 3 | krasnoselkup
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 3 | pacifica
# Processing Record 40 of Set 3 | caraubas
# Processing Record 41 of Set 3 | zabid
# Processing Record 42 of Set 3 | ambilobe
# Processing Record 43 of Set 3 | quelimane
# Processing Record 44 of Set 3 | faya
# Processing Record 45 of Set 3 | quatre cocos
# Processing Record 46 of Set 3 | vao
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | rabo de peixe
# Processing Record 1 of Set 4 | paamiut
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | tarhunah
# City not found. Skipping...
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | sola
# Processing Record 6 of Set 4 | huarmey
# Processing Record 7 of Set 4 | vardo
# Processing Record 8 of Set 4 | myaundzha
# Processing Record 9 of Set 4 | valencia
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | pangody
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | vestmannaeyjar
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | mayor pablo lagerenza
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | payo
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | qaanaaq
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | kloulklubed
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | meulaboh
# Processing Record 24 of Set 4 | vanimo
# Processing Record 25 of Set 4 | sicamous
# Processing Record 26 of Set 4 | makakilo city
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | tual
# Processing Record 29 of Set 4 | strandby
# Processing Record 30 of Set 4 | marapanim
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | geraldton
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | ossora
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 4 | magadan
# Processing Record 39 of Set 4 | kysyl-syr
# Processing Record 40 of Set 4 | baykit
# Processing Record 41 of Set 4 | sistranda
# Processing Record 42 of Set 4 | caibarien
# Processing Record 43 of Set 4 | abu samrah
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | pitimbu
# Processing Record 46 of Set 4 | maryborough
# Processing Record 47 of Set 4 | mincivan
# Processing Record 48 of Set 4 | xichang
# Processing Record 49 of Set 4 | magaria
# Processing Record 50 of Set 4 | mount gambier
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | boa vista
# Processing Record 3 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 4 of Set 5 | champerico
# Processing Record 5 of Set 5 | buin
# Processing Record 6 of Set 5 | cap malheureux
# Processing Record 7 of Set 5 | richards bay
# Processing Record 8 of Set 5 | bjala
# City not found. Skipping...
# Processing Record 9 of Set 5 | urucara
# Processing Record 10 of Set 5 | nizhniy odes
# Processing Record 11 of Set 5 | tura
# Processing Record 12 of Set 5 | oyem
# Processing Record 13 of Set 5 | kidal
# Processing Record 14 of Set 5 | albany
# Processing Record 15 of Set 5 | oistins
# Processing Record 16 of Set 5 | bac lieu
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | culipapa
# City not found. Skipping...
# Processing Record 19 of Set 5 | sampit
# Processing Record 20 of Set 5 | karangasem
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | kovdor
# Processing Record 23 of Set 5 | wajir
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | kinsale
# Processing Record 26 of Set 5 | bredasdorp
# Processing Record 27 of Set 5 | north bend
# Processing Record 28 of Set 5 | johnson city
# Processing Record 29 of Set 5 | gauribidanur
# Processing Record 30 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 5 | vila do maio
# Processing Record 32 of Set 5 | chase
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | cabedelo
# Processing Record 35 of Set 5 | nhulunbuy
# Processing Record 36 of Set 5 | kpalime
# Processing Record 37 of Set 5 | carauari
# Processing Record 38 of Set 5 | lata
# Processing Record 39 of Set 5 | nuuk
# Processing Record 40 of Set 5 | maningrida
# Processing Record 41 of Set 5 | voyvozh
# Processing Record 42 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 5 | betsiamites
# Processing Record 44 of Set 5 | kudahuvadhoo
# Processing Record 45 of Set 5 | kano
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | poronaysk
# Processing Record 48 of Set 5 | capreol
# Processing Record 49 of Set 5 | lisakovsk
# Processing Record 50 of Set 5 | beamsville
# Processing Record 1 of Set 6 | wanaka
# Processing Record 2 of Set 6 | tornio
# Processing Record 3 of Set 6 | tessalit
# Processing Record 4 of Set 6 | nemuro
# Processing Record 5 of Set 6 | rantepao
# Processing Record 6 of Set 6 | bluff
# Processing Record 7 of Set 6 | akyab
# Processing Record 8 of Set 6 | necochea
# Processing Record 9 of Set 6 | redmond
# Processing Record 10 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 6 | gillette
# Processing Record 12 of Set 6 | hualmay
# Processing Record 13 of Set 6 | havelock
# Processing Record 14 of Set 6 | srikakulam
# Processing Record 15 of Set 6 | hofn
# Processing Record 16 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 6 | nikolskoye
# Processing Record 18 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | hermanus
# Processing Record 20 of Set 6 | smithers
# Processing Record 21 of Set 6 | jamestown
# Processing Record 22 of Set 6 | esil
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | nakambala
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | morros
# Processing Record 27 of Set 6 | ilmajoki
# Processing Record 28 of Set 6 | vicuna
# Processing Record 29 of Set 6 | saint-francois
# Processing Record 30 of Set 6 | ocos
# Processing Record 31 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 6 | lyuban
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | silver city
# Processing Record 35 of Set 6 | manggar
# Processing Record 36 of Set 6 | upernavik
# Processing Record 37 of Set 6 | moron
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | mandalgovi
# Processing Record 40 of Set 6 | aklavik
# Processing Record 41 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 6 | mangan
# Processing Record 43 of Set 6 | doha
# Processing Record 44 of Set 6 | kokopo
# Processing Record 45 of Set 6 | nelson bay
# Processing Record 46 of Set 6 | birpur
# Processing Record 47 of Set 6 | songjianghe
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | punta arenas
# Processing Record 50 of Set 6 | mangrol
# Processing Record 1 of Set 7 | sangar
# Processing Record 2 of Set 7 | carupano
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | taungdwingyi
# Processing Record 5 of Set 7 | chapais
# Processing Record 6 of Set 7 | camopi
# Processing Record 7 of Set 7 | atasu
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 11 of Set 7 | dikson
# Processing Record 12 of Set 7 | bud
# Processing Record 13 of Set 7 | ostrovnoy
# Processing Record 14 of Set 7 | narsaq
# Processing Record 15 of Set 7 | montepuez
# Processing Record 16 of Set 7 | luorong
# Processing Record 17 of Set 7 | kachiry
# Processing Record 18 of Set 7 | belyy yar
# Processing Record 19 of Set 7 | fortuna
# Processing Record 20 of Set 7 | acarau
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | nanortalik
# Processing Record 23 of Set 7 | odesskoye
# Processing Record 24 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 7 | aksarka
# Processing Record 26 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 7 | rundu
# Processing Record 28 of Set 7 | spornoye
# Processing Record 29 of Set 7 | samarai
# Processing Record 30 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 7 | dolinsk
# Processing Record 32 of Set 7 | praxedis guerrero
# Processing Record 33 of Set 7 | san-pedro
# Processing Record 34 of Set 7 | jardim
# Processing Record 35 of Set 7 | hurghada
# Processing Record 36 of Set 7 | yangjiang
# Processing Record 37 of Set 7 | ribeira grande
# Processing Record 38 of Set 7 | alice springs
# Processing Record 39 of Set 7 | luoyang
# Processing Record 40 of Set 7 | bardiyah
# Processing Record 41 of Set 7 | hervey bay
# Processing Record 42 of Set 7 | zhigansk
# Processing Record 43 of Set 7 | oranjestad
# Processing Record 44 of Set 7 | ambon
# Processing Record 45 of Set 7 | orangeburg
# Processing Record 46 of Set 7 | veraval
# Processing Record 47 of Set 7 | daliao
# Processing Record 48 of Set 7 | fort morgan
# Processing Record 49 of Set 7 | isangel
# Processing Record 50 of Set 7 | ayan
# Processing Record 1 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 8 | fairbanks
# Processing Record 5 of Set 8 | luganville
# Processing Record 6 of Set 8 | roald
# Processing Record 7 of Set 8 | middle island
# Processing Record 8 of Set 8 | solnechnyy
# Processing Record 9 of Set 8 | gusau
# Processing Record 10 of Set 8 | buala
# Processing Record 11 of Set 8 | port blair
# Processing Record 12 of Set 8 | omsukchan
# Processing Record 13 of Set 8 | ushuaia
# Processing Record 14 of Set 8 | kismayo
# Processing Record 15 of Set 8 | natal
# Processing Record 16 of Set 8 | college
# Processing Record 17 of Set 8 | nakatsu
# Processing Record 18 of Set 8 | achutupo
# Processing Record 19 of Set 8 | zapolyarnyy
# Processing Record 20 of Set 8 | caravelas
# Processing Record 21 of Set 8 | aljezur
# Processing Record 22 of Set 8 | soyo
# Processing Record 23 of Set 8 | roura
# Processing Record 24 of Set 8 | sunland park
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | zaraza
# Processing Record 27 of Set 8 | christchurch
# Processing Record 28 of Set 8 | ryotsu
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | abha
# Processing Record 31 of Set 8 | najran
# Processing Record 32 of Set 8 | talcahuano
# Processing Record 33 of Set 8 | sibolga
# Processing Record 34 of Set 8 | hengyang
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | fernley
# Processing Record 37 of Set 8 | salalah
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | ulaangom
# Processing Record 40 of Set 8 | iqaluit
# Processing Record 41 of Set 8 | rafaela
# Processing Record 42 of Set 8 | metro
# Processing Record 43 of Set 8 | houma
# Processing Record 44 of Set 8 | iberia
# Processing Record 45 of Set 8 | banda aceh
# Processing Record 46 of Set 8 | yumen
# Processing Record 47 of Set 8 | zilair
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 8 | tsabong
# Processing Record 1 of Set 9 | mareeba
# Processing Record 2 of Set 9 | shingu
# Processing Record 3 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 9 | neuquen
# Processing Record 5 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 9 | oranjemund
# Processing Record 7 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 9 | vung tau
# Processing Record 9 of Set 9 | kunszentmarton
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | alzamay
# Processing Record 12 of Set 9 | altagracia de orituco
# Processing Record 13 of Set 9 | tigil
# Processing Record 14 of Set 9 | izumo
# Processing Record 15 of Set 9 | norden
# Processing Record 16 of Set 9 | charleville-mezieres
# Processing Record 17 of Set 9 | tiksi
# Processing Record 18 of Set 9 | dingle
# Processing Record 19 of Set 9 | thyboron
# Processing Record 20 of Set 9 | belaya gora
# Processing Record 21 of Set 9 | new norfolk
# Processing Record 22 of Set 9 | pascagoula
# Processing Record 23 of Set 9 | marfino
# Processing Record 24 of Set 9 | hobart
# Processing Record 25 of Set 9 | kijang
# Processing Record 26 of Set 9 | nyurba
# Processing Record 27 of Set 9 | poopo
# Processing Record 28 of Set 9 | kumluca
# Processing Record 29 of Set 9 | angouleme
# Processing Record 30 of Set 9 | sechura
# Processing Record 31 of Set 9 | sao felix do xingu
# Processing Record 32 of Set 9 | bulgan
# Processing Record 33 of Set 9 | hobyo
# Processing Record 34 of Set 9 | bairiki
# Processing Record 35 of Set 9 | grindavik
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | coquimbo
# Processing Record 38 of Set 9 | huejuquilla el alto
# Processing Record 39 of Set 9 | namtsy
# Processing Record 40 of Set 9 | sinnamary
# Processing Record 41 of Set 9 | amuntai
# Processing Record 42 of Set 9 | benguela
# Processing Record 43 of Set 9 | lasem
# Processing Record 44 of Set 9 | okha
# Processing Record 45 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 9 | kurilsk
# Processing Record 47 of Set 9 | sao miguel do araguaia
# Processing Record 48 of Set 9 | shar
# Processing Record 49 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 50 of Set 9 | padang
# Processing Record 1 of Set 10 | namibe
# Processing Record 2 of Set 10 | marsh harbour
# Processing Record 3 of Set 10 | nantucket
# Processing Record 4 of Set 10 | hovd
# Processing Record 5 of Set 10 | whitehorse
# Processing Record 6 of Set 10 | vila franca do campo
# Processing Record 7 of Set 10 | santa rosa de lima
# Processing Record 8 of Set 10 | udachnyy
# Processing Record 9 of Set 10 | tocopilla
# Processing Record 10 of Set 10 | manokwari
# Processing Record 11 of Set 10 | skibbereen
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | cherskiy
# Processing Record 14 of Set 10 | merrill
# Processing Record 15 of Set 10 | kenora
# Processing Record 16 of Set 10 | leshukonskoye
# Processing Record 17 of Set 10 | gimli
# Processing Record 18 of Set 10 | la ronge
# Processing Record 19 of Set 10 | yeppoon
# Processing Record 20 of Set 10 | bakel
# Processing Record 21 of Set 10 | clyde river
# Processing Record 22 of Set 10 | boo
# Processing Record 23 of Set 10 | brawley
# Processing Record 24 of Set 10 | comodoro rivadavia
# Processing Record 25 of Set 10 | hirara
# Processing Record 26 of Set 10 | birjand
# Processing Record 27 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 10 | bredy
# Processing Record 29 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 30 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 10 | bonavista
# Processing Record 32 of Set 10 | pevek
# Processing Record 33 of Set 10 | missoula
# Processing Record 34 of Set 10 | kiama
# Processing Record 35 of Set 10 | belen
# Processing Record 36 of Set 10 | skelleftea
# Processing Record 37 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 10 | granville
# Processing Record 39 of Set 10 | fountain hills
# Processing Record 40 of Set 10 | abnub
# Processing Record 41 of Set 10 | port alfred
# Processing Record 42 of Set 10 | kindu
# Processing Record 43 of Set 10 | kirovsk
# Processing Record 44 of Set 10 | jeronimo monteiro
# Processing Record 45 of Set 10 | kathmandu
# Processing Record 46 of Set 10 | hay river
# Processing Record 47 of Set 10 | luau
# Processing Record 48 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 49 of Set 10 | cortland
# Processing Record 50 of Set 10 | alice town
# Processing Record 1 of Set 11 | dalhousie
# Processing Record 2 of Set 11 | dali
# Processing Record 3 of Set 11 | mehamn
# Processing Record 4 of Set 11 | aden
# Processing Record 5 of Set 11 | kaabong
# Processing Record 6 of Set 11 | letterkenny
# Processing Record 7 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 8 of Set 11 | rudbar
# Processing Record 9 of Set 11 | santa cruz
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | korla
# Processing Record 12 of Set 11 | ponta delgada
# Processing Record 13 of Set 11 | cururupu
# Processing Record 14 of Set 11 | henties bay
# Processing Record 15 of Set 11 | mzimba
# Processing Record 16 of Set 11 | saint-philippe
# Processing Record 17 of Set 11 | gulu
# Processing Record 18 of Set 11 | balykshi
# Processing Record 19 of Set 11 | aromashevo
# Processing Record 20 of Set 11 | deputatskiy
# Processing Record 21 of Set 11 | gizo
# Processing Record 22 of Set 11 | la asuncion
# Processing Record 23 of Set 11 | varnamo
# Processing Record 24 of Set 11 | masumbwe
# Processing Record 25 of Set 11 | west bay
# Processing Record 26 of Set 11 | strelka
# Processing Record 27 of Set 11 | nouakchott
# Processing Record 28 of Set 11 | pandan
# Processing Record 29 of Set 11 | soto
# Processing Record 30 of Set 11 | kenai
# Processing Record 31 of Set 11 | tucuman
# Processing Record 32 of Set 11 | atbasar
# Processing Record 33 of Set 11 | bosaso
# Processing Record 34 of Set 11 | rio verde de mato grosso
# Processing Record 35 of Set 11 | norfolk
# Processing Record 36 of Set 11 | hami
# Processing Record 37 of Set 11 | bratsk
# Processing Record 38 of Set 11 | puerto del rosario
# Processing Record 39 of Set 11 | erenhot
# Processing Record 40 of Set 11 | bubaque
# Processing Record 41 of Set 11 | kurchatov
# Processing Record 42 of Set 11 | hun
# Processing Record 43 of Set 11 | ketchikan
# Processing Record 44 of Set 11 | buritis
# Processing Record 45 of Set 11 | tegh
# Processing Record 46 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 11 | eresos
# Processing Record 48 of Set 11 | murdochville
# Processing Record 49 of Set 11 | rypefjord
# Processing Record 50 of Set 11 | angoram
# Processing Record 1 of Set 12 | menongue
# Processing Record 2 of Set 12 | kavaratti
# Processing Record 3 of Set 12 | orange cove
# Processing Record 4 of Set 12 | miri
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | joshimath
# Processing Record 7 of Set 12 | sao domingos
# Processing Record 8 of Set 12 | kingsport
# Processing Record 9 of Set 12 | presidencia roque saenz pena
# Processing Record 10 of Set 12 | chalon-sur-saone
# Processing Record 11 of Set 12 | sukhumi
# Processing Record 12 of Set 12 | riyadh
# Processing Record 13 of Set 12 | banepa
# Processing Record 14 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 12 | gat
# Processing Record 16 of Set 12 | ambovombe
# Processing Record 17 of Set 12 | kyaikto
# Processing Record 18 of Set 12 | zhezkazgan
# Processing Record 19 of Set 12 | magway
# Processing Record 20 of Set 12 | ternate
# Processing Record 21 of Set 12 | yalutorovsk
# Processing Record 22 of Set 12 | port hardy
# Processing Record 23 of Set 12 | ust-tsilma
# Processing Record 24 of Set 12 | megion
# Processing Record 25 of Set 12 | santa maria
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | whitianga
# Processing Record 28 of Set 12 | derbent
# Processing Record 29 of Set 12 | katsuura
# Processing Record 30 of Set 12 | trzcianka
# Processing Record 31 of Set 12 | cockburn town
# Processing Record 32 of Set 12 | bacolod
# Processing Record 33 of Set 12 | avera
# Processing Record 34 of Set 12 | outlook
# Processing Record 35 of Set 12 | goderich
# Processing Record 36 of Set 12 | bartlesville
# Processing Record 37 of Set 12 | roma
# Processing Record 38 of Set 12 | san rafael
# Processing Record 39 of Set 12 | mecca
# Processing Record 40 of Set 12 | morbegno
# Processing Record 41 of Set 12 | loukhi
# Processing Record 42 of Set 12 | moose factory
# Processing Record 43 of Set 12 | carballo
# Processing Record 44 of Set 12 | auki
# Processing Record 45 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 12 | pontes e lacerda
# Processing Record 47 of Set 12 | eureka
# Processing Record 48 of Set 12 | beringovskiy
# Processing Record 49 of Set 12 | bilma
# Processing Record 50 of Set 12 | payson
# Processing Record 1 of Set 13 | chornukhy
# Processing Record 2 of Set 13 | seymchan
# Processing Record 3 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 13 | bethanien
# Processing Record 5 of Set 13 | scottsbluff
# Processing Record 6 of Set 13 | galesong
# Processing Record 7 of Set 13 | olafsvik
# Processing Record 8 of Set 13 | luanda
# Processing Record 9 of Set 13 | suluq
# Processing Record 10 of Set 13 | dunedin
# Processing Record 11 of Set 13 | erzin
# Processing Record 12 of Set 13 | kargasok
# Processing Record 13 of Set 13 | kununurra
# Processing Record 14 of Set 13 | bahadurganj
# Processing Record 15 of Set 13 | los llanos de aridane
# Processing Record 16 of Set 13 | sikeston
# Processing Record 17 of Set 13 | kungurtug
# Processing Record 18 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 13 | cotacachi
# Processing Record 22 of Set 13 | coihaique
# Processing Record 23 of Set 13 | graciano sanchez
# Processing Record 24 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 13 | lima
# Processing Record 27 of Set 13 | mastic beach
# Processing Record 28 of Set 13 | dargaville
# Processing Record 29 of Set 13 | arona
# Processing Record 30 of Set 13 | contamana
# Processing Record 31 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 13 | dudinka
# Processing Record 33 of Set 13 | byron bay
# Processing Record 34 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 13 | tanout
# Processing Record 36 of Set 13 | broken hill
# Processing Record 37 of Set 13 | charlestown
# Processing Record 38 of Set 13 | say
# Processing Record 39 of Set 13 | guisa
# Processing Record 40 of Set 13 | nador
# Processing Record 41 of Set 13 | kruisfontein
# Processing Record 42 of Set 13 | tuktoyaktuk
# Processing Record 43 of Set 13 | nabire
# Processing Record 44 of Set 13 | ingham
# Processing Record 45 of Set 13 | anadyr
# Processing Record 46 of Set 13 | boli
# Processing Record 47 of Set 13 | magan
# Processing Record 48 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 13 | erdenet
# Processing Record 50 of Set 13 | tucumcari
# Processing Record 1 of Set 14 | pedasi
# Processing Record 2 of Set 14 | nome
# Processing Record 3 of Set 14 | beira
# Processing Record 4 of Set 14 | wilson
# Processing Record 5 of Set 14 | batagay-alyta
# Processing Record 6 of Set 14 | maceio
# Processing Record 7 of Set 14 | truro
# Processing Record 8 of Set 14 | hays
# Processing Record 9 of Set 14 | fortuna foothills
# Processing Record 10 of Set 14 | mglin
# Processing Record 11 of Set 14 | idar-oberstein
# Processing Record 12 of Set 14 | fort-shevchenko
# Processing Record 13 of Set 14 | san cristobal
# Processing Record 14 of Set 14 | viedma
# Processing Record 15 of Set 14 | karratha
# Processing Record 16 of Set 14 | morehead
# Processing Record 17 of Set 14 | sakaiminato
# Processing Record 18 of Set 14 | concarneau
# Processing Record 19 of Set 14 | camacha
# Processing Record 20 of Set 14 | ellisras
# Processing Record 21 of Set 14 | bell ville
# Processing Record 22 of Set 14 | sri aman
# Processing Record 23 of Set 14 | labuhan
# Processing Record 24 of Set 14 | shawnee
# Processing Record 25 of Set 14 | binga
# Processing Record 26 of Set 14 | cilegon
# Processing Record 27 of Set 14 | prainha
# Processing Record 28 of Set 14 | northam
# Processing Record 29 of Set 14 | arkhipo-osipovka
# Processing Record 30 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 14 | sai buri
# Processing Record 32 of Set 14 | loreto
# Processing Record 33 of Set 14 | sexsmith
# Processing Record 34 of Set 14 | kanniyakumari
# Processing Record 35 of Set 14 | celestun
# Processing Record 36 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 14 | sao gabriel da cachoeira
# Processing Record 38 of Set 14 | sarkand
# Processing Record 39 of Set 14 | coos bay
# Processing Record 40 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 14 | nacozari
# Processing Record 42 of Set 14 | victor harbor
# Processing Record 43 of Set 14 | timmins
# Processing Record 44 of Set 14 | prince albert
# Processing Record 45 of Set 14 | berlevag
# Processing Record 46 of Set 14 | dalnerechensk
# Processing Record 47 of Set 14 | tawang
# Processing Record 48 of Set 14 | asyut
# Processing Record 49 of Set 14 | grand gaube
# Processing Record 50 of Set 14 | nicoya
# Processing Record 1 of Set 15 | bima
# Processing Record 2 of Set 15 | rey bouba
# Processing Record 3 of Set 15 | silleda
# Processing Record 4 of Set 15 | eyl
# Processing Record 5 of Set 15 | maloyaz
# City not found. Skipping...
# Processing Record 6 of Set 15 | chapayeve
# Processing Record 7 of Set 15 | kashi
# Processing Record 8 of Set 15 | villa bruzual
# Processing Record 9 of Set 15 | maraa
# Processing Record 10 of Set 15 | taltal
# Processing Record 11 of Set 15 | bagdarin
# Processing Record 12 of Set 15 | jalu
# Processing Record 13 of Set 15 | payakumbuh
# Processing Record 14 of Set 15 | rio grande
# Processing Record 15 of Set 15 | cookeville
# Processing Record 16 of Set 15 | sar-e pul
# Processing Record 17 of Set 15 | tyup
# Processing Record 18 of Set 15 | baraboo
# Processing Record 19 of Set 15 | whitehaven
# Processing Record 20 of Set 15 | bastia
# Processing Record 21 of Set 15 | fomboni
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | barra
# Processing Record 24 of Set 15 | monster
# Processing Record 25 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 15 | chumikan
# Processing Record 27 of Set 15 | elasson
# City not found. Skipping...
# Processing Record 28 of Set 15 | olga
# Processing Record 29 of Set 15 | la entrada
# Processing Record 30 of Set 15 | taphan hin
# Processing Record 31 of Set 15 | racale
# Processing Record 32 of Set 15 | imeni poliny osipenko
# Processing Record 33 of Set 15 | bentiu
# Processing Record 34 of Set 15 | imbituba
# Processing Record 35 of Set 15 | taoudenni
# Processing Record 36 of Set 15 | mirabad
# Processing Record 37 of Set 15 | beatrice
# Processing Record 38 of Set 15 | puerto colombia
# Processing Record 39 of Set 15 | fayaoue
# Processing Record 40 of Set 15 | mercedes
# Processing Record 41 of Set 15 | enkoping
# Processing Record 42 of Set 15 | changli
# Processing Record 43 of Set 15 | marzuq
# Processing Record 44 of Set 15 | amazar
# Processing Record 45 of Set 15 | cobourg
# Processing Record 46 of Set 15 | antigonish
# Processing Record 47 of Set 15 | puerto leguizamo
# Processing Record 48 of Set 15 | harper
# Processing Record 49 of Set 15 | arrecife
# Processing Record 50 of Set 15 | copiapo
# Processing Record 1 of Set 16 | gazojak
# Processing Record 2 of Set 16 | puerto escondido
# Processing Record 3 of Set 16 | murgab
# Processing Record 4 of Set 16 | sitka
# Processing Record 5 of Set 16 | tuatapere
# Processing Record 6 of Set 16 | marawi
# Processing Record 7 of Set 16 | malpe
# Processing Record 8 of Set 16 | honningsvag
# Processing Record 9 of Set 16 | greensburg
# Processing Record 10 of Set 16 | torrington
# Processing Record 11 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 16 | kaeo
# Processing Record 13 of Set 16 | kibala
# Processing Record 14 of Set 16 | dwarka
# Processing Record 15 of Set 16 | balakhta
# Processing Record 16 of Set 16 | kakonko
# Processing Record 17 of Set 16 | batagay
# Processing Record 18 of Set 16 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 16 | muscat
# Processing Record 20 of Set 16 | tucurui
# Processing Record 21 of Set 16 | tonantins
# Processing Record 22 of Set 16 | marrakesh
# Processing Record 23 of Set 16 | asosa
# Processing Record 24 of Set 16 | buchanan
# Processing Record 25 of Set 16 | abu dhabi
# Processing Record 26 of Set 16 | kamenka
# Processing Record 27 of Set 16 | yatou
# Processing Record 28 of Set 16 | riberalta
# Processing Record 29 of Set 16 | terracina
# Processing Record 30 of Set 16 | formosa
# Processing Record 31 of Set 16 | batemans bay
# Processing Record 32 of Set 16 | sao jose da coroa grande
# Processing Record 33 of Set 16 | suraia
# Processing Record 34 of Set 16 | lazaro cardenas
# Processing Record 35 of Set 16 | breves
# Processing Record 36 of Set 16 | valparaiso
# Processing Record 37 of Set 16 | alofi
# Processing Record 38 of Set 16 | noumea
# Processing Record 39 of Set 16 | strezhevoy
# Processing Record 40 of Set 16 | kyren
# Processing Record 41 of Set 16 | puri
# Processing Record 42 of Set 16 | zhigalovo
# Processing Record 43 of Set 16 | dolores
# Processing Record 44 of Set 16 | lixourion
# Processing Record 45 of Set 16 | chegdomyn
# Processing Record 46 of Set 16 | talnakh
# Processing Record 47 of Set 16 | piacabucu
# Processing Record 48 of Set 16 | edson
# Processing Record 49 of Set 16 | xapuri
# Processing Record 50 of Set 16 | ahlat
# Processing Record 1 of Set 17 | surt
# Processing Record 2 of Set 17 | pochutla
# Processing Record 3 of Set 17 | port moresby
# Processing Record 4 of Set 17 | waddan
# Processing Record 5 of Set 17 | talas
# Processing Record 6 of Set 17 | songea
# Processing Record 7 of Set 17 | den helder
# Processing Record 8 of Set 17 | mocuba
# Processing Record 9 of Set 17 | bintulu
# Processing Record 10 of Set 17 | broome
# Processing Record 11 of Set 17 | alta floresta
# Processing Record 12 of Set 17 | walvis bay
# Processing Record 13 of Set 17 | camargo
# Processing Record 14 of Set 17 | bedford
# Processing Record 15 of Set 17 | east london
# Processing Record 16 of Set 17 | mananjary
# Processing Record 17 of Set 17 | killybegs
# Processing Record 18 of Set 17 | lowestoft
# Processing Record 19 of Set 17 | antofagasta
# Processing Record 20 of Set 17 | adrar
# Processing Record 21 of Set 17 | arman
# Processing Record 22 of Set 17 | druzhba
# Processing Record 23 of Set 17 | kaoma
# Processing Record 24 of Set 17 | sao sebastiao
# Processing Record 25 of Set 17 | langsa
# Processing Record 26 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 17 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 17 | maragogi
# Processing Record 29 of Set 17 | jijiga
# Processing Record 30 of Set 17 | boatlaname
# City not found. Skipping...
# Processing Record 31 of Set 17 | edd
# Processing Record 32 of Set 17 | calvia
# Processing Record 33 of Set 17 | tabuk
# Processing Record 34 of Set 17 | sur
# Processing Record 35 of Set 17 | tarakan
# Processing Record 36 of Set 17 | shetpe
# Processing Record 37 of Set 17 | lakes entrance
# Processing Record 38 of Set 17 | vaitape
# Processing Record 39 of Set 17 | ialibu
# Processing Record 40 of Set 17 | itaqui
# Processing Record 41 of Set 17 | rolim de moura
# City not found. Skipping...
# Processing Record 42 of Set 17 | morgan city
# Processing Record 43 of Set 17 | bandarbeyla
# Processing Record 44 of Set 17 | muros
# Processing Record 45 of Set 17 | progreso
# Processing Record 46 of Set 17 | mbengwi
# Processing Record 47 of Set 17 | dvinskoy
# Processing Record 48 of Set 17 | qarchi gak
# Processing Record 49 of Set 17 | anloga
# Processing Record 50 of Set 17 | lubango
# Processing Record 1 of Set 18 | borogontsy
# Processing Record 2 of Set 18 | le pradet
# Processing Record 3 of Set 18 | kalabo
# Processing Record 4 of Set 18 | chimore
# Processing Record 5 of Set 18 | ulaanbaatar
# Processing Record 6 of Set 18 | stolbovaya
# Processing Record 7 of Set 18 | otane
# Processing Record 8 of Set 18 | neka
# Processing Record 9 of Set 18 | plavsk
# Processing Record 10 of Set 18 | alyangula
# Processing Record 11 of Set 18 | pindwara
# Processing Record 12 of Set 18 | rio grande city
# Processing Record 13 of Set 18 | matara
# Processing Record 14 of Set 18 | dhidhdhoo
# Processing Record 15 of Set 18 | imperia
# Processing Record 16 of Set 18 | guhagar
# Processing Record 17 of Set 18 | dabat
# Processing Record 18 of Set 18 | karakol
# Processing Record 19 of Set 18 | empalme
# Processing Record 20 of Set 18 | baruun-urt
# Processing Record 21 of Set 18 | batabano
# Processing Record 22 of Set 18 | makokou
# Processing Record 23 of Set 18 | clarence town
# Processing Record 24 of Set 18 | daru
# Processing Record 25 of Set 18 | esso
# Processing Record 26 of Set 18 | palimbang
# Processing Record 27 of Set 18 | mae sot
# Processing Record 28 of Set 18 | tymovskoye
# Processing Record 29 of Set 18 | bambanglipuro
# Processing Record 30 of Set 18 | hastings
# Processing Record 31 of Set 18 | leningradskiy
# Processing Record 32 of Set 18 | bharuch
# Processing Record 33 of Set 18 | sergeyevka
# Processing Record 34 of Set 18 | monte alegre
# Processing Record 35 of Set 18 | davila
# Processing Record 36 of Set 18 | junagarh
# Processing Record 37 of Set 18 | aripuana
# Processing Record 38 of Set 18 | yuanping
# Processing Record 39 of Set 18 | pierre
# Processing Record 40 of Set 18 | jizan
# Processing Record 41 of Set 18 | sakakah
# Processing Record 42 of Set 18 | choix
# Processing Record 43 of Set 18 | xingyi
# Processing Record 44 of Set 18 | togur
# Processing Record 45 of Set 18 | san felipe
# Processing Record 46 of Set 18 | jasper
# Processing Record 47 of Set 18 | godfrey
# Processing Record 48 of Set 18 | nazilli
# Processing Record 49 of Set 18 | tapes
# Processing Record 50 of Set 18 | selma
# Processing Record 1 of Set 19 | newtownards
# Processing Record 2 of Set 19 | rosita
# Processing Record 3 of Set 19 | edosaki
# Processing Record 4 of Set 19 | gayny
# Processing Record 5 of Set 19 | pamanukan
# Processing Record 6 of Set 19 | egvekinot
# Processing Record 7 of Set 19 | ust-kuyga
# Processing Record 8 of Set 19 | bilibino
# Processing Record 9 of Set 19 | beroroha
# Processing Record 10 of Set 19 | mayskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 843

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hithadhoo  -0.6000   73.0833     82.08        63          34
# 1     Georgetown   5.4112  100.3354     78.73        93          20
# 2       Kirakira -10.4544  161.9205     83.05        81         100
# 3     Deniliquin -35.5333  144.9667     59.90        85         100
# 4    Provideniya  64.3833 -173.3000      3.36        78          75
# 5        Pokhara  28.2333   83.9833     69.53        45          26
# 6  Mar Del Plata -38.0023  -57.5575     64.09        90          75
# 7    Zhanakorgan  43.9098   67.2495     59.40        57          76
# 8        Rikitea -23.1203 -134.9692     79.39        73           4
# 9        Tautira -17.7333 -149.1500     82.17        75          25
#
#    Wind Speed       Description Country
# 0        4.45  scattered clouds      MV
# 1        3.44        few clouds      MY
# 2       11.72   overcast clouds      SB
# 3       13.69        light rain      AU
# 4        7.00        light snow      RU
# 5        5.64  scattered clouds      NP
# 6       11.99     broken clouds      AR
# 7        5.37     moderate rain      KZ
# 8       16.28         clear sky      PF
# 9       19.53        light rain      PF

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hithadhoo      MV  -0.6000   73.0833     82.08        63          34
# 1     Georgetown      MY   5.4112  100.3354     78.73        93          20
# 2       Kirakira      SB -10.4544  161.9205     83.05        81         100
# 3     Deniliquin      AU -35.5333  144.9667     59.90        85         100
# 4    Provideniya      RU  64.3833 -173.3000      3.36        78          75
# 5        Pokhara      NP  28.2333   83.9833     69.53        45          26
# 6  Mar Del Plata      AR -38.0023  -57.5575     64.09        90          75
# 7    Zhanakorgan      KZ  43.9098   67.2495     59.40        57          76
# 8        Rikitea      PF -23.1203 -134.9692     79.39        73           4
# 9        Tautira      PF -17.7333 -149.1500     82.17        75          25
#
#    Wind Speed       Description
# 0        4.45  scattered clouds
# 1        3.44        few clouds
# 2       11.72   overcast clouds
# 3       13.69        light rain
# 4        7.00        light snow
# 5        5.64  scattered clouds
# 6       11.99     broken clouds
# 7        5.37     moderate rain
# 8       16.28         clear sky
# 9       19.53        light rain

# %%
# Create output CSV
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
